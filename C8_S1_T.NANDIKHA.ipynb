# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\drsar\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\drsar\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\drsar\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\drsar\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\drsar\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\drsar\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Load the datasets from Excel files
appearances = pd.read_excel('appearances.xlsx')
game_events = pd.read_excel('game_events.xlsx')
games = pd.read_excel('games.xlsx')
game_lineups = pd.read_excel('game_lineups.xlsx')
players = pd.read_excel('players.xlsx')

# Merge datasets
merged_data = pd.merge(appearances, game_events, on=['game_id', 'player_id'], how='left')
merged_data = pd.merge(merged_data, games, on='game_id', how='left')
merged_data = pd.merge(merged_data, game_lineups, on=['game_id', 'player_id'], how='left')
merged_data = pd.merge(merged_data, players, on='player_id', how='left')

# Identify redundant columns to drop
columns_to_drop = [
    'date_x', 'date_y', 'player_name_x', 'player_name_y', 
    'competition_id_x', 'competition_id_y', 'type_x', 'type_y', 
    'position_x', 'position_y'
]

# Drop the identified redundant columns
merged_data = merged_data.drop(columns=columns_to_drop)

# Handle null values
# Fill null values with the mean for numerical columns, adjust for other columns as necessary
merged_data['minutes_played'].fillna(merged_data['minutes_played'].mean(), inplace=True)
# Add more null value handling as needed

# Save the cleaned and merged data to an Excel file
merged_data.to_excel('Football_data_merged_cleaned.xlsx', index=False)

# Create data dictionary
data_dictionary = pd.DataFrame({
    'Column Name': merged_data.columns,
    'Data Type': [str(dtype) for dtype in merged_data.dtypes]
})
data_dictionary.to_excel('football_data_dictionary.xlsx', index=False)

print("Data merging and cleaning complete. Files saved as 'Football_data_merged_cleaned.xlsx' and 'football_data_dictionary.xlsx'.")
# Out:
# Data merging and cleaning complete. Files saved as 'Football_data_merged_cleaned.xlsx' and 'football_data_dictionary.xlsx'.

# %%
import pandas as pd

# Step 2: Load the Excel file
file_path = r"C:\Users\drsar\Downloads\C8\Football_data_merged_cleaned.xlsx"
df = pd.read_excel(file_path)

# Step 3: Inspect the data
print(df.head())  # Display the first few rows
print(df.info())  # Display the data info
print(df.isnull().sum())  # Check for missing values

# Step 4: Handle missing values
# Drop rows with missing values
df_cleaned = df.dropna()

# Or fill missing values
# df_cleaned = df.fillna(value)

# Step 5: Remove duplicates
df_cleaned = df_cleaned.drop_duplicates()

# Step 6: Convert data types if necessary
# df_cleaned['column_name'] = df_cleaned['column_name'].astype('desired_type')

# Step 7: Save the cleaned data
output_file_path = r"Football_data_merged_cleaned_data.xlsx"
df_cleaned.to_excel(output_file_path, index=False)

print("Data cleaning process completed. Cleaned data saved to:", output_file_path)
# Out:
#     appearance_id  game_id  player_id  yellow_cards  red_cards  goals  \
# 0  2224728_119169  2224728     119169             0          0      0
# 1  2224732_161244  2224732     161244             0          0      1
# 2   2224729_39467  2224729      39467             0          0      0
# 3  2232104_119169  2232104     119169             0          0      0
# 4   2219794_39475  2219794      39475             0          0      0
#
#    assists  minutes_played                     game_event_id  minute  ...  \
# 0        0              90                               NaN     NaN  ...
# 1        0              90  d9f02a9d767f319e58909ba1e1de6d23    50.0  ...
# 2        0              90                               NaN     NaN  ...
# 3        0              74  2ab0ea7af8313c0da07c723728bb6a49    74.0  ...
# 4        0               3                               NaN     NaN  ...
#
#         player_code  country_of_birth  date_of_birth        sub_position  \
# 0   aron-johannsson     United States     1990-11-10      Centre-Forward
# 1      conor-obrien     United States     1988-10-20  Defensive Midfield
# 2  clarence-goodson     United States     1982-05-17         Centre-Back
# 3   aron-johannsson     United States     1990-11-10      Centre-Forward
# 4    sacha-kljestan     United States     1985-09-09  Attacking Midfield
#
#     foot height_in_cm  market_value_in_eur  highest_market_value_in_eur  \
# 0  right        184.0             400000.0                      4000000
# 1  right        177.0                  NaN                       750000
# 2  right        193.0                  NaN                      1850000
# 3  right        184.0             400000.0                      4000000
# 4   both        185.0                  NaN                      3000000
#
#    contract_expiration_date   agent_name
# 0                2024-12-31  CAA Stellar
# 1                       NaT          NaN
# 2                       NaT          NaN
# 3                2024-12-31  CAA Stellar
# 4                       NaT    Wasserman
#
# [5 rows x 47 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3722 entries, 0 to 3721
# Data columns (total 47 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   appearance_id                3722 non-null   object
#  1   game_id                      3722 non-null   int64
#  2   player_id                    3722 non-null   int64
#  3   yellow_cards                 3722 non-null   int64
#  4   red_cards                    3722 non-null   int64
#  5   goals                        3722 non-null   int64
#  6   assists                      3722 non-null   int64
#  7   minutes_played               3722 non-null   int64
#  8   game_event_id                1122 non-null   object
#  9   minute                       1122 non-null   float64
#  10  description                  667 non-null    object
#  11  player_in_id                 619 non-null    float64
#  12  player_assist_id             118 non-null    float64
#  13  season                       3722 non-null   int64
#  14  round                        3722 non-null   object
#  15  date                         3722 non-null   datetime64[ns]
#  16  home_club_goals              3722 non-null   int64
#  17  away_club_goals              3722 non-null   int64
#  18  home_club_position           3180 non-null   float64
#  19  away_club_position           3180 non-null   float64
#  20  home_club_manager_name       3716 non-null   object
#  21  away_club_manager_name       3716 non-null   object
#  22  stadium                      3722 non-null   object
#  23  attendance                   3586 non-null   float64
#  24  referee                      3718 non-null   object
#  25  home_club_formation          0 non-null      float64
#  26  away_club_formation          0 non-null      float64
#  27  home_club_name               3596 non-null   object
#  28  away_club_name               3656 non-null   object
#  29  aggregate                    3722 non-null   object
#  30  competition_type             3722 non-null   object
#  31  game_lineups_id              0 non-null      float64
#  32  number                       0 non-null      float64
#  33  team_captain                 0 non-null      float64
#  34  name                         3722 non-null   object
#  35  last_season                  3722 non-null   int64
#  36  current_club_id              3722 non-null   int64
#  37  player_code                  3722 non-null   object
#  38  country_of_birth             3722 non-null   object
#  39  date_of_birth                3722 non-null   datetime64[ns]
#  40  sub_position                 3722 non-null   object
#  41  foot                         3631 non-null   object
#  42  height_in_cm                 3670 non-null   float64
#  43  market_value_in_eur          2461 non-null   float64
#  44  highest_market_value_in_eur  3722 non-null   int64
#  45  contract_expiration_date     2330 non-null   datetime64[ns]
#  46  agent_name                   2641 non-null   object
# dtypes: datetime64[ns](3), float64(13), int64(13), object(18)
# memory usage: 1.3+ MB
# None
# appearance_id                     0
# game_id                           0
# player_id                         0
# yellow_cards                      0
# red_cards                         0
# goals                             0
# assists                           0
# minutes_played                    0
# game_event_id                  2600
# minute                         2600
# description                    3055
# player_in_id                   3103
# player_assist_id               3604
# season                            0
# round                             0
# date                              0
# home_club_goals                   0
# away_club_goals                   0
# home_club_position              542
# away_club_position              542
# home_club_manager_name            6
# away_club_manager_name            6
# stadium                           0
# attendance                      136
# referee                           4
# home_club_formation            3722
# away_club_formation            3722
# home_club_name                  126
# away_club_name                   66
# aggregate                         0
# competition_type                  0
# game_lineups_id                3722
# number                         3722
# team_captain                   3722
# name                              0
# last_season                       0
# current_club_id                   0
# player_code                       0
# country_of_birth                  0
# date_of_birth                     0
# sub_position                      0
# foot                             91
# height_in_cm                     52
# market_value_in_eur            1261
# highest_market_value_in_eur       0
# contract_expiration_date       1392
# agent_name                     1081
# dtype: int64
# Data cleaning process completed. Cleaned data saved to: Football_data_merged_cleaned_data.xlsx

# %%
import pandas as pd

# Step 1: Load the Excel file
file_path = "Football_data_merged_cleaned.xlsx"
df = pd.read_excel(file_path)

# Step 2: Drop columns that contain all missing values
df = df.dropna(axis=1, how='all')

# Step 3: Fill missing values in specific columns with predefined values
fill_missing_values = {
    'game_event_id': 'unknown',
    'minute': 0,
    'description': 'unknown',
    'player_in_id': 0,
    'player_assist_id': 0,
    'home_club_position': 0,
    'away_club_position': 0,
    'home_club_manager_name': 'unknown',
    'away_club_manager_name': 'unknown',
    'stadium': 'unknown',
    'attendance': df['attendance'].mean(),
    'referee': 'unknown',
    'home_club_name': 'unknown',
    'away_club_name': 'unknown',
    'foot': 'unknown',
    'height_in_cm': df['height_in_cm'].mean(),
    'market_value_in_eur': df['market_value_in_eur'].mean(),
    'contract_expiration_date': pd.Timestamp('1900-01-01'),
    'agent_name': 'unknown'
}

df.fillna(value=fill_missing_values, inplace=True)

# Step 4: Remove duplicate rows
df_cleaned = df.drop_duplicates()

# Step 5: Save the cleaned data to a new Excel file
output_file_path = "Football_data_merged_cleaned_data.xlsx"
df_cleaned.to_excel(output_file_path, index=False)

print("Data cleaning process completed. Cleaned data saved to:", output_file_path)
# Out:
# Data cleaning process completed. Cleaned data saved to: Football_data_merged_cleaned_data.xlsx
